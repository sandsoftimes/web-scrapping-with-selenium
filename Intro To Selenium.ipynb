# %%
pip install selenium
# Out:
# Collecting selenium
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/fc/df/a8972c41279fc9e9404cad87bc1f4d6d3d824b84c5c072dca0e986a89680/selenium-4.14.0-py3-none-any.whl.metadata
#   Downloading selenium-4.14.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /home/saleemshady/anaconda3/lib/python3.11/site-packages (from selenium) (1.26.16)
# Collecting trio~=0.17 (from selenium)
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/a3/dd/b61fa61b186d3267ef3903048fbee29132963ae762fb70b08d4a3cd6f7aa/trio-0.22.2-py3-none-any.whl.metadata
#   Downloading trio-0.22.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl.metadata
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /home/saleemshady/anaconda3/lib/python3.11/site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /home/saleemshady/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in /home/saleemshady/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /home/saleemshady/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in /home/saleemshady/anaconda3/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.2.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /home/saleemshady/anaconda3/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 871.9 kB/s eta 0:00:00MB/s eta 0:00:01
# Downloading selenium-4.14.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 378.2 kB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading trio-0.22.2-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.2/400.2 kB 445.0 kB/s eta 0:00:001m454.5 kB/s eta 0:00:01
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.2.0 selenium-4.14.0 trio-0.22.2 trio-websocket-0.11.1 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # To Check Selenium Version

# %%
from selenium import __version__
# Print the Selenium version.
print(__version__)

# %% [markdown]
# # Starting Code

# %%
from selenium import webdriver
website = 'https://www.adamchoi.co.uk/overs/detailed'  # Define which site to scrape
driver = webdriver.Chrome()  # Define the driver variable
driver.get(website)

driver.quit()

# %%
all_matches_button=driver.find_element_by_xpath('//label[@analytics-event="All matches"]')
all_matches_button.click() #click() to click a button

# %%
from selenium import webdriver
website = 'https://www.adamchoi.co.uk/overs/detailed'  # Define which site to scrape
driver = webdriver.Chrome()  # Define the driver variable
driver.get(website)

all_matches_button=driver.find_element_by_xpath('//label[@analytics-event="All matches"]')
all_matches_button.click() #click() to click a button

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-518c4dd65408> in <module>
#       4 driver.get(website)
#       5
# ----> 6 all_matches_button=driver.find_element_by_xpath('//label[@analytics-event="All matches"]')
#       7 all_matches_button.click() #click() to click a button
#       8
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_xpath'

# %%
from selenium import webdriver

website = 'https://www.adamchoi.co.uk/overs/detailed'
driver = webdriver.Chrome()
driver.get(website)

all_matches_button = driver.find_element('xpath','//label[@analytics-event="All matches"]')
all_matches_button.click()

# driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

website = 'https://www.adamchoi.co.uk/overs/detailed'
driver = webdriver.Chrome()
driver.get(website)

all_matches_button = driver.find_element('xpath','//label[@analytics-event="All matches"]')
all_matches_button.click()


matches=driver.find_elements(By.TAG_NAME, "tr")
for match in matches:
    print(match.text)

# driver.quit()
# Out:
# 12-08-2023 Arsenal 2 - 1 Nott'm Forest
# 21-08-2023 Crystal Palace 0 - 1 Arsenal
# 26-08-2023 Arsenal 2 - 2 Fulham
# 03-09-2023 Arsenal 3 - 1 Man United
# 17-09-2023 Everton 0 - 1 Arsenal
# 24-09-2023 Arsenal 2 - 2 Tottenham
# 30-09-2023 Bournemouth 0 - 4 Arsenal
# 08-10-2023 Arsenal 1 - 0 Man City
# 21-10-2023 Chelsea ? - ? Arsenal
# 12-08-2023 Newcastle 5 - 1 Aston Villa
# 20-08-2023 Aston Villa 4 - 0 Everton
# 27-08-2023 Burnley 1 - 3 Aston Villa
# 03-09-2023 Liverpool 3 - 0 Aston Villa
# 16-09-2023 Aston Villa 3 - 1 Crystal Palace
# 24-09-2023 Chelsea 0 - 1 Aston Villa
# 30-09-2023 Aston Villa 6 - 1 Brighton
# 08-10-2023 Wolves 1 - 1 Aston Villa
# 22-10-2023 Aston Villa ? - ? West Ham
# 12-08-2023 Bournemouth 1 - 1 West Ham
# 19-08-2023 Liverpool 3 - 1 Bournemouth
# 18-08-2023 Nott'm Forest 2 - 1 Sheffield United
# 27-08-2023 Sheffield United 1 - 2 Man City
# 02-09-2023 Sheffield United 2 - 2 Everton
# 16-09-2023 Tottenham 2 - 1 Sheffield United
# 24-09-2023 Sheffield United 0 - 8 Newcastle
# 30-09-2023 West Ham 2 - 0 Sheffield United
# 07-10-2023 Fulham 3 - 1 Sheffield United
# 21-10-2023 Sheffield United ? - ? Man United
# 13-08-2023 Brentford 2 - 2 Tottenham
# 19-08-2023 Tottenham 2 - 0 Man United
# 26-08-2023 Bournemouth 0 - 2 Tottenham
# 02-09-2023 Burnley 2 - 5 Tottenham
# 16-09-2023 Tottenham 2 - 1 Sheffield United
# 24-09-2023 Arsenal 2 - 2 Tottenham
# 30-09-2023 Tottenham 2 - 1 Liverpool
# 07-10-2023 Luton 0 - 1 Tottenham
# 23-10-2023 Tottenham ? - ? Fulham
# 12-08-2023 Bournemouth 1 - 1 West Ham
# 20-08-2023 West Ham 3 - 1 Chelsea
# 26-08-2023 Brighton 1 - 3 West Ham
# 01-09-2023 Luton 1 - 2 West Ham
# 16-09-2023 West Ham 1 - 3 Man City
# 24-09-2023 Liverpool 3 - 1 West Ham
# 30-09-2023 West Ham 2 - 0 Sheffield United
# 08-10-2023 West Ham 2 - 2 Newcastle
# 22-10-2023 Aston Villa ? - ? West Ham
# 14-08-2023 Man United 1 - 0 Wolves
# 19-08-2023 Wolves 1 - 4 Brighton
# 26-08-2023 Everton 0 - 1 Wolves
# 03-09-2023 Crystal Palace 3 - 2 Wolves
# 16-09-2023 Wolves 1 - 3 Liverpool
# 23-09-2023 Luton 1 - 1 Wolves
# 30-09-2023 Wolves 2 - 1 Man City
# 08-10-2023 Wolves 1 - 1 Aston Villa
# 21-10-2023 Bournemouth ? - ? Wolves

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

website = 'https://www.adamchoi.co.uk/overs/detailed'
driver = webdriver.Chrome()
driver.get(website)

all_matches_button = driver.find_element('xpath','//label[@analytics-event="All matches"]')
all_matches_button.click()


matches=driver.find_elements(By.TAG_NAME, "tr") #This will have list of all rows (tr) as we are using find_elements

date=[] # To store values of date column of all rows
home_team=[] # To store values of home_team column of all rows
score=[] # To store values of score column of all rows
away_team=[] # To store values of away_team column of all rows

for match in matches: # this loop will take 1 room at a time from the rows list
    date.append(match.find_element('xpath','./td[1]').text) #append column 1 data of match row in date list
    home=match.find_element('xpath','./td[2]').text #store column 2 data of match row in home variable
    home_team.append(home) #append home variable value in home_team list
    print(home) #printing home variable
    score.append(match.find_element('xpath','./td[3]').text) #append column 3 data of match row in score list
    away_team.append(match.find_element('xpath','./td[4]').text) #append column 4 data of match row in date list

# driver.quit()
# Out:
# Arsenal
# Crystal Palace
# Arsenal
# Arsenal
# Everton
# Arsenal
# Bournemouth
# Arsenal
# Chelsea
# Newcastle
# Aston Villa
# Burnley
# Liverpool
# Aston Villa
# Chelsea
# Aston Villa
# Wolves
# Aston Villa
# Bournemouth
# Liverpool
# Bournemouth
# Brentford
# Bournemouth
# Brighton
# Bournemouth
# Everton
# Bournemouth
# Brentford
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-4-dd287de2746c> in <module>
#      18
#      19 for match in matches: # this loop will take 1 room at a time from the rows list
# ---> 20     date.append(match.find_element('xpath','./td[1]').text) #append column 1 data of match row in date list
#      21     home=match.find_element('xpath','./td[2]').text #store column 2 data of match row in home variable
#      22     home_team.append(home) #append home variable value in home_team list
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     414             value = f'[name="{value}"]'
#     415
# --> 416         return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#     417
#     418     def find_elements(self, by=By.ID, value=None) -> list[WebElement]:
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     392             params = {}
#     393         params["id"] = self._id
# --> 394         return self._parent.execute(command, params)
#     395
#     396     def find_element(self, by=By.ID, value=None) -> WebElement:
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# --> 344             self.error_handler.check_response(response)
#     345             response["value"] = self._unwrap_value(response.get("value", None))
#     346             return response
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=117.0.5938.149)
# Stacktrace:
# #0 0x563167881933 <unknown>
# #1 0x56316755b6f7 <unknown>
# #2 0x563167534558 <unknown>
# #3 0x5631675c996f <unknown>
# #4 0x5631675dd3ab <unknown>
# #5 0x5631675c43d3 <unknown>
# #6 0x563167596e64 <unknown>
# #7 0x563167597c4e <unknown>
# #8 0x563167847558 <unknown>
# #9 0x56316784b4a0 <unknown>
# #10 0x56316785597c <unknown>
# #11 0x56316784c0b8 <unknown>
# #12 0x563167817cdf <unknown>
# #13 0x563167870048 <unknown>
# #14 0x563167870219 <unknown>
# #15 0x563167880ac3 <unknown>
# #16 0x7f965ecec609 start_thread

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd # pd is a short name for pandas now
    

website = 'https://www.adamchoi.co.uk/overs/detailed'
driver = webdriver.Chrome()
driver.get(website)

all_matches_button = driver.find_element('xpath','//label[@analytics-event="All matches"]')
all_matches_button.click()


matches=driver.find_elements(By.TAG_NAME, "tr") #This will have list of all rows (tr) as we are using find_elements

date=[] # To store values of date column of all rows
home_team=[] # To store values of home_team column of all rows
score=[] # To store values of score column of all rows
away_team=[] # To store values of away_team column of all rows

for match in matches: # this loop will take 1 room at a time from the rows list
    date.append(match.find_element('xpath','./td[1]').text) #append column 1 data of match row in date list
    home=match.find_element('xpath','./td[2]').text #store column 2 data of match row in home variable
    home_team.append(home) #append home variable value in home_team list
    print(home) #printing home variable
    score.append(match.find_element('xpath','./td[3]').text) #append column 3 data of match row in score list
    away_team.append(match.find_element('xpath','./td[4]').text) #append column 4 data of match row in date list

driver.quit()

df=pd.DataFrame({'date':date,'home_team':home_team,'score':score,'away_team':away_team}) # 'Key':List(e.g date,home_team .e.t.c)
df.to_csv('football_data.csv',index=False)
print(df)
# Out:
# Arsenal
# Crystal Palace
# Arsenal
# Arsenal
# Everton
# Arsenal
# Bournemouth
# Arsenal
# Chelsea
# Newcastle
# Aston Villa
# Burnley
# Liverpool
# Aston Villa
# Chelsea
# Aston Villa
# Wolves
# Aston Villa
# Bournemouth
# Liverpool
# Bournemouth
# Brentford
# Bournemouth
# Brighton
# Bournemouth
# Everton
# Bournemouth
# Brentford
# Fulham
# Brentford
# Brentford
# Newcastle
# Brentford
# Nott'm Forest
# Man United
# Brentford
# Brighton
# Wolves
# Brighton
# Brighton
# Man United
# Brighton
# Aston Villa
# Brighton
# Man City
# Burnley
# Burnley
# Burnley
# Nott'm Forest
# Burnley
# Newcastle
# Luton
# Burnley
# Brentford
# Chelsea
# West Ham
# Chelsea
# Chelsea
# Bournemouth
# Chelsea
# Fulham
# Burnley
# Chelsea
# Sheffield United
# Crystal Palace
# Brentford
# Crystal Palace
# Aston Villa
# Crystal Palace
# Man United
# Crystal Palace
# Newcastle
# Everton
# Aston Villa
# Everton
# Sheffield United
# Everton
# Brentford
# Everton
# Everton
# Liverpool
# Everton
# Fulham
# Arsenal
# Man City
# Fulham
# Crystal Palace
# Fulham
# Fulham
# Tottenham
# Chelsea
# Liverpool
# Newcastle
# Liverpool
# Wolves
# Liverpool
# Tottenham
# Brighton
# Liverpool
# Brighton
# Chelsea
# Luton
# Fulham
# Luton
# Everton
# Luton
# Luton
# Nott'm Forest
# Burnley
# Man City
# Sheffield United
# Man City
# West Ham
# Man City
# Wolves
# Arsenal
# Man City
# Man United
# Tottenham
# Man United
# Arsenal
# Man United
# Burnley
# Man United
# Man United
# Sheffield United
# Newcastle
# Man City
# Newcastle
# Brighton
# Newcastle
# Sheffield United
# Newcastle
# West Ham
# Newcastle
# Arsenal
# Nott'm Forest
# Man United
# Chelsea
# Nott'm Forest
# Man City
# Nott'm Forest
# Crystal Palace
# Nott'm Forest
# Sheffield United
# Nott'm Forest
# Sheffield United
# Sheffield United
# Tottenham
# Sheffield United
# West Ham
# Fulham
# Sheffield United
# Brentford
# Tottenham
# Bournemouth
# Burnley
# Tottenham
# Arsenal
# Tottenham
# Luton
# Tottenham
# Bournemouth
# West Ham
# Brighton
# Luton
# West Ham
# Liverpool
# West Ham
# West Ham
# Aston Villa
# Man United
# Wolves
# Everton
# Crystal Palace
# Wolves
# Luton
# Wolves
# Wolves
# Bournemouth
#            date       home_team  score      away_team
# 0    12-08-2023         Arsenal  2 - 1  Nott'm Forest
# 1    21-08-2023  Crystal Palace  0 - 1        Arsenal
# 2    26-08-2023         Arsenal  2 - 2         Fulham
# 3    03-09-2023         Arsenal  3 - 1     Man United
# 4    17-09-2023         Everton  0 - 1        Arsenal
# ..          ...             ...    ...            ...
# 175  16-09-2023          Wolves  1 - 3      Liverpool
# 176  23-09-2023           Luton  1 - 1         Wolves
# 177  30-09-2023          Wolves  2 - 1       Man City
# 178  08-10-2023          Wolves  1 - 1    Aston Villa
# 179  21-10-2023     Bournemouth  ? - ?         Wolves
#
# [180 rows x 4 columns]

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
import pandas as pd # pd is a short name for pandas now
import time

website = 'https://www.adamchoi.co.uk/overs/detailed'
driver = webdriver.Chrome()
driver.get(website)

all_matches_button = driver.find_element('xpath','//label[@analytics-event="All matches"]')
all_matches_button.click()

dropdown=Select(driver.find_element(By.ID,'country'))
dropdown.select_by_visible_text('Spain')

time.sleep(3)

matches=driver.find_elements(By.TAG_NAME, "tr") #This will have list of all rows (tr) as we are using find_elements

date=[] # To store values of date column of all rows
home_team=[] # To store values of home_team column of all rows
score=[] # To store values of score column of all rows
away_team=[] # To store values of away_team column of all rows

for match in matches: # this loop will take 1 room at a time from the rows list
    date.append(match.find_element('xpath','./td[1]').text) #append column 1 data of match row in date list
    home=match.find_element('xpath','./td[2]').text #store column 2 data of match row in home variable
    home_team.append(home) #append home variable value in home_team list
    print(home) #printing home variable
    score.append(match.find_element('xpath','./td[3]').text) #append column 3 data of match row in score list
    away_team.append(match.find_element('xpath','./td[4]').text) #append column 4 data of match row in date list

driver.quit()

df=pd.DataFrame({'date':date,'home_team':home_team,'score':score,'away_team':away_team}) # 'Key':List(e.g date,home_team .e.t.c)
df.to_csv('football_data.csv',index=False)
print(df)
# Out:
# Cadiz
# Alaves
# Getafe
